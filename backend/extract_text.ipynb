# %%
import speech_recognition as sr
import pyttsx3

# Initialize the recognizer
r = sr.Recognizer()


# Function to convert text to speech
def SpeakText(command):
    # Initialize the engine
    engine = pyttsx3.init()
    engine.say(command)
    engine.runAndWait()


# List available microphones
print("Available Microphones:")
for index, name in enumerate(sr.Microphone.list_microphone_names()):
    print(f"{index}: {name}")

# Use the first available microphone or specify the index you want to use
mic_index = 0  # Change this if needed
with sr.Microphone(device_index=mic_index) as source2:
    # Adjusting for ambient noise if needed
    r.adjust_for_ambient_noise(source2, duration=0.2)

    while True:
        try:
            print("Start listening")
            audio2 = r.listen(source2, timeout=10.0, phrase_time_limit=5.0)
            print("Done listening")

            # Using Google to recognize audio
            MyText = r.recognize_google(audio2)
            MyText = MyText.lower()

            print(f"Did you say {MyText}")
            SpeakText(MyText)

        except sr.RequestError as e:
            print(f"Could not request results; {e}")

        except sr.UnknownValueError:
            print("unknown error occurred")
# Out:
# Available Microphones:
# 0: Microsoft Sound Mapper - Input
# 1: Microphone Array (Realtek(R) Au
# 2: AI Noise-cancelling Input (ASUS
# 3: Microsoft Sound Mapper - Output
# 4: Speakers (Realtek(R) Audio)
# 5: AI Noise-cancelling Output (ASU
# 6: Primary Sound Capture Driver
# 7: Microphone Array (Realtek(R) Audio)
# 8: AI Noise-cancelling Input (ASUS Utility)
# 9: Primary Sound Driver
# 10: Speakers (Realtek(R) Audio)
# 11: AI Noise-cancelling Output (ASUS Utility)
# 12: Speakers (Realtek(R) Audio)
# 13: AI Noise-cancelling Output (ASUS Utility)
# 14: Microphone Array (Realtek(R) Audio)
# 15: AI Noise-cancelling Input (ASUS Utility)
# 16: Headphones (Realtek HD Audio 2nd output)
# 17: Microphone Array (Realtek HD Audio Mic Array input)
# 18: Microphone (Realtek HD Audio Mic input)
# 19: Speakers 1 (Realtek HD Audio output with HAP)
# 20: Speakers 2 (Realtek HD Audio output with HAP)
# 21: PC Speaker (Realtek HD Audio output with HAP)
# 22: Stereo Mix (Realtek HD Audio Stereo input)
# 23: Headphones ()
# 24: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(CosmoBuds X200))
# 25: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(CosmoBuds X200))
# 26: Headphones ()
# 27: Speakers ()
# 28: Speakers ()
# 29: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(JBL TUNE500BT))
# 30: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(JBL TUNE500BT))
# 31: AI Noise-cancelling Input (Intelligo VAC (W))
# 32: Line Out 1 (Intelligo VAC (W))
# 33: System Virtual Line (Intelligo VAC (W))
# 34: Line Out 2 (Intelligo VAC (W))
# 35: Headphones ()
# 36: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Gouthamâ€™s Beats Studio Pro))
# 37: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Gouthamâ€™s Beats Studio Pro))
# Start listening
# Done listening
# unknown error occurred
# Start listening
# Done listening
# Did you say hello how are you
# Start listening
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 30
#      28 try:
#      29     print("Start listening")
# ---> 30     audio2 = r.listen(source2, timeout=10.0, phrase_time_limit=5.0)
#      31     print("Done listening")
#      33     # Using Google to recognize audio
#
# File ~\anaconda3\Lib\site-packages\speech_recognition\__init__.py:523, in Recognizer.listen(self, source, timeout, phrase_time_limit, snowboy_configuration)
#     520 if phrase_time_limit and elapsed_time - phrase_start_time > phrase_time_limit:
#     521     break
# --> 523 buffer = source.stream.read(source.CHUNK)
#     524 if len(buffer) == 0: break  # reached end of the stream
#     525 frames.append(buffer)
#
# File ~\anaconda3\Lib\site-packages\speech_recognition\__init__.py:199, in Microphone.MicrophoneStream.read(self, size)
#     198 def read(self, size):
# --> 199     return self.pyaudio_stream.read(size, exception_on_overflow=False)
#
# File ~\anaconda3\Lib\site-packages\pyaudio\__init__.py:570, in PyAudio.Stream.read(self, num_frames, exception_on_overflow)
#     567 if not self._is_input:
#     568     raise IOError("Not input stream",
#     569                   paCanNotReadFromAnOutputOnlyStream)
# --> 570 return pa.read_stream(self._stream, num_frames,
#     571                       exception_on_overflow)
#
# KeyboardInterrupt:
